# %% [markdown]
# # 作業1
#
# 我選擇Titanic: Machine Learning from Disaster
#
# 1.因為它很有趣，再者找到存活率高的變因，或許有助大型海運的災難救援。
#
# 2.船上的乘客名單，及救災紀錄。
#
# 3.標準的結構化資料，有多個變因(乘客性別、年齡、票價等)，及受否存活。
#
# 4.統計在存活的條件下，那些變因的那些狀態最多，即可得知倖存乘客的資料樣貌。
#
# -----

# %% [markdown]
# # 作業2
#
# 1.最終目的為提升業績。乘車收費標準有法所規，加上屏除其他外部因素，我最能控制的，就是提升每位司機的產值，即是降低每台計程車閒置率，亦即盡可能增加上班時間每台車輛同時行走與載客的時間比。
#
# 2.計程車有兩種大宗載客模式，一是據點招攬載客，透過統計，可得知地區的那些據點的車輛，平均閒置率低。
# 二是路途招攬，在據點出發的車輛，行走那些路途較可能在回程，乘載到客人以降低閒置率(先不論拒載是否違法)。為達成以上目標，資料可從每台計程車的衛星導航紀錄(很多車隊都有)取得，以及車輛是否載客，也可由運將操作資訊系統取得。
#
# 3.依第二題，蒐集來的資料會有兩類，皆為結構化資料。據點載客有據點位置、車輛的閒置時間。第二類是固定據點，到車輛回到據點的時間內，經由不同路途，車輛的閒置時間。但是很難區分兩種變因個別的閒置時間，因此應該是多個變因欄位，一個閒置時間欄位。
#
# 4.依照第三題，我可以得到一個類似於線性的模型(y=ax+bx+c)，這個模型應是能降低車輛閒置率的，可由MAE做驗證。
#
# -----

# %% [markdown]
# # 作業3

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# MSE
def mean_squared_error(y, y_hat):
    mse = MSE = sum(abs(y-y_hat)**2) / len(y)
    return mse

# %%
# MAE
def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 225.764
# The Mean absolute error is 11.747
